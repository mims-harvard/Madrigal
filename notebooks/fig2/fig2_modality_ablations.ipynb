# %%
import pandas as pd
import numpy as np
import os

import torch
from tqdm import tqdm

import matplotlib.pyplot as plt
import matplotlib
from madrigal.evaluate.predict import get_data_for_analysis, make_predictions
from madrigal.evaluate.metrics import get_metrics, get_metrics_binary
from madrigal.utils import BASE_DIR
# %matplotlib inline
# Out:
# No CUDA runtime is found, using CUDA_HOME='$CUDA_HOME/'
# ['str', 'kg', 'cv']

# %%
raw_drugbank_df = pd.read_pickle('../raw_drugbank_df.pkl')

drug_metadata = pd.read_pickle(os.path.join(BASE_DIR, 'processed_data/drug_features/drug_metadata_ddi.pkl'))
drug_metadata['view_str'] = 1
drug_metadata = drug_metadata[drug_metadata['drugbank_ddi'] == 1].reset_index().merge(raw_drugbank_df, left_on='node_id', right_on='drugbank_id', how='left')
drug_metadata = drug_metadata.set_index('drug_index')

to_keep = ['node_id', 'drug_name', 'moa', 'description', 'indication_y', 'pharmacodynamics'] + [col for col in drug_metadata.columns if col.startswith('view')]
drug_metadata = drug_metadata[to_keep]

# %% [markdown]
# ## Label stratified

# %%
data_source = "DrugBank"
split_method = "split_by_drugs_random"
epoch = None
repeat = None
kg_encoder = "hgt"
device = torch.device("cpu")

checkpoint_dir = BASE_DIR + f"model_output/{data_source}/{split_method}/madrigal_seed42/"

train_batches, _, test_batches_1, label_map = get_data_for_analysis(
    data_source=data_source, kg_encoder=kg_encoder, split_method=split_method, repeat=repeat, 
    path_base=BASE_DIR+"processed_data/", checkpoint_dir=checkpoint_dir
    )

# %%
def get_label_metrics(model_type, checkpoint, eval_type):
    checkpoint_dir = BASE_DIR + f"model_output/{data_source}/{split_method}/{checkpoint}"
    ckpt = checkpoint_dir + "best_model.pt"
    
    if model_type == 'str_ablation':
        finetune_mode = "ablation_str_str"
    else:
        finetune_mode = "str_str+random_sample"
    
    # test between
    batch = test_batches_1[0]
    ddi_labels = batch['edge_indices']['label']
    ddi_pos_neg_samples = batch['edge_indices']['pos_neg'].float()
    true_ddis = ddi_pos_neg_samples
    label_map_valid = np.array(label_map)[np.unique(ddi_labels)]
    
    pred_ddis = make_predictions(ckpt, 
                                 batch, 
                                 eval_type, 
                                 finetune_mode, 
                                 device)  # expect to see two printings of missing keys, the first one containing "covariates_embeddings.0.weight"

    metrics, pos_samples = get_metrics(
        pred_ddis.numpy(), 
        true_ddis.numpy(), 
        ddi_labels.numpy(), 
        k=50, 
        task='multiclass', 
        average=None, 
        logger=None, 
        verbose=False, 
    )

    test_between_scores = pd.DataFrame({
        "label_ind":np.unique(ddi_labels),
        'label':label_map_valid, 
        'specificity':metrics['specificity'], 
        'npv':metrics['npv'], 
        'auprc':metrics['auprc'], 
        'auroc':metrics['auroc'], 
        'num_pos_sample':pos_samples.astype(int)
    }).sort_values('label')
    
    return pred_ddis, test_between_scores

# %%
_, str_scores = get_label_metrics(model_type='str_ablation', 
                  checkpoint="structure_only_no_pretrain_seed42/", 
                  eval_type='full_full')
# Out:
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}

# %%
_, no_pretrain_scores = get_label_metrics(model_type='no_pretrain', 
                  checkpoint="no_pretrain_seed42/",
                  eval_type='str_full')
# Out:
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}

# %%
_, pretrain_scores = get_label_metrics(model_type='pretrain', 
                  checkpoint="madrigal_seed42/",
                  eval_type='str_full')
# Out:
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}

# %%
all_metrics = pd.DataFrame({'label':pretrain_scores['label'], 
                            'Struc. only\nw/o CL': str_scores['auprc'],
                            'W/o CL': no_pretrain_scores['auprc'],
                            'Madrigal': pretrain_scores['auprc']})
all_metrics_long = all_metrics.melt(value_vars=['Struc. only\nw/o CL', 'W/o CL', 'Madrigal'], var_name='Model type', value_name='AUPRC')

from scipy.stats import wilcoxon
print(wilcoxon(str_scores['auprc'], no_pretrain_scores['auprc'], alternative='two-sided'))
print(wilcoxon(no_pretrain_scores['auprc'], pretrain_scores['auprc'], alternative='two-sided'))
# Out:
# WilcoxonResult(statistic=2021.0, pvalue=6.1428560371336866e-09)
# WilcoxonResult(statistic=2527.0, pvalue=3.676092383472578e-06)

# %%
import seaborn as sns
from matplotlib import font_manager as fm
arial_path = "../arial.ttf"
try:
    fm.fontManager.addfont(arial_path)
except OSError:
    pass
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']

plt.figure(figsize=(6, 3), dpi=300)

sns.set(style="ticks", context="paper", font_scale=2)
ax = sns.boxplot(data=all_metrics_long, x="Model type", y="AUPRC", 
                 showfliers=False,
                 fill=False, color="dimgrey", width=0.6)
sns.stripplot(data=all_metrics_long, x="Model type", y="AUPRC", ax=ax, color="grey", alpha=0.4)

plt.ylim(0.35, 1.05)
plt.yticks(np.arange(0.4, 1.01, 0.1))
sns.despine()
plt.savefig('./fig2_label_stratified_model_comparison_bottleneck.svg', dpi=300, format="svg")
plt.show()

# %% [markdown]
# ## Drug stratified (modality availability)

# %%
import copy
from itertools import combinations

batch = copy.deepcopy(test_batches_1[0])
between_train_drugs = batch['tail']['drugs'].cpu().numpy()
between_test_drugs = batch['head']['drugs'].cpu().numpy()

between_train_drugs_modality_availability = drug_metadata[[col for col in drug_metadata.columns if col.startswith('view_')]].loc[between_train_drugs]
between_train_drug_to_index = {k:i for i,k in enumerate(between_train_drugs_modality_availability.index)}

view_tx_columns = [col for col in between_train_drugs_modality_availability.columns if col.startswith('view_tx')]

# Step 2: Identify the other columns
other_columns = [col for col in between_train_drugs_modality_availability.columns if not col.startswith('view_tx')]

# TRAIN
# Step 3: Filter rows
# For 'view_tx' columns, check if any column has a value of 1
condition_tx_train = between_train_drugs_modality_availability[view_tx_columns].any(axis=1)

# For the other columns, check if all have a value of 1
condition_others_train = between_train_drugs_modality_availability[other_columns].all(axis=1)

# Apply conditions
between_train_all_modality_available = between_train_drugs_modality_availability[condition_tx_train & condition_others_train].index.tolist()

between_train_set_all_modality = set(between_train_all_modality_available)
keep_ddi_train_full = []
for i, drug_t in tqdm(enumerate(batch["edge_indices"]["tail"])):
    if batch["tail"]["drugs"][drug_t].item() in between_train_set_all_modality:
        keep_ddi_train_full.append(i)
# Out:
# 1165476it [00:02, 522441.82it/s]

# %%
def batch_mask_mutate(batch, full_modality_drug_inds, avail_mods, head_or_tails):
    """
    If controling modalities for test drugs, `head_or_tails` = ["head"];
    If controling modalities for train drugs, `head_or_tails` = ["tail"];
    o.w. `head_or_tails` = ["head", "tail"].
    """
    to_force_mask = list(set([0,1,2,3]) - set(avail_mods))
    
    for head_or_tail in head_or_tails:
        for i in range(len(batch[head_or_tail]["drugs"])):
            if batch[head_or_tail]["drugs"][i].item() in full_modality_drug_inds:
                for j in to_force_mask:
                    if j < 3:
                        batch[head_or_tail]["masks"][i, j] = True
                    else:
                        batch[head_or_tail]["masks"][i, 3:] = True
    
    return batch

# %%
def get_label_metrics_all_mod_train(model_type, checkpoint, eval_type, full_mod_drug_set, keep_ddi, head_or_tails = ["head"]):
    checkpoint_dir = BASE_DIR + f"model_output/{data_source}/{split_method}/{checkpoint}"
    ckpt = checkpoint_dir + "best_model.pt"
    finetune_mode = "str_str+random_sample"
        
    batch = test_batches_1[0]
    ddi_pos_neg_samples = batch["edge_indices"]["pos_neg"].float()
    true_ddis = ddi_pos_neg_samples
    
    avail_mods_all_combs = [()] + list(combinations([1,2,3], 1)) + list(combinations([1,2,3], 2)) + list(combinations([1,2,3], 3))
    all_auprc = []
    
    for avail_mods in tqdm(avail_mods_all_combs):
        avail_mods = [0] + list(avail_mods)
        new_batch = batch_mask_mutate(copy.deepcopy(batch), full_mod_drug_set, avail_mods, head_or_tails)
        pred_ddis = make_predictions(ckpt, 
                                     new_batch, 
                                     eval_type, 
                                     finetune_mode, 
                                     device)  # expect to see two printings of missing keys, the first one containing "covariates_embeddings.0.weight"
        
        metrics = get_metrics_binary(pred_ddis.numpy()[keep_ddi], true_ddis.numpy()[keep_ddi], k=50)
        metrics = [metric_value for metric_value, metric_name in zip(*metrics)][0]
        all_auprc.append(metrics)
    
    return all_auprc, avail_mods_all_combs

# %% [markdown]
# ### For full-modality drugs
# Mask train drugs, str-full

# %%
# Mask train drugs, str-full
mask_train_str_full_all_auprc, avail_mods_all_combs = get_label_metrics_all_mod_train(
    model_type="pretrain", 
    checkpoint="madrigal_seed42/", 
    eval_type="str_full", 
    full_mod_drug_set=between_train_set_all_modality,  # between_test_set_all_modality
    keep_ddi=keep_ddi_train_full, 
    head_or_tails=["tail"],
)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
#  12%|█▎        | 1/8 [00:46<05:23, 46.19s/it]
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}

# %%
labels = ['Struc.', 'Struc.\nPKG', 'Struc.\nCV', 'Struc.\nTrans.', 'Struc.\nPKG\nCV', 'Struc.\nPKG\nTrans.', 'Struc.\nCV\nTrans.', 'Struc.\nPKG\nCV\nTrans.']

plt.figure(figsize=(8, 3), dpi=300)
sns.set(style="ticks", context="paper", font_scale=2)
sns.barplot(pd.DataFrame.from_dict({
    "AUPRC": mask_train_str_full_all_auprc, 
    "Available modalities": labels
}), x="Available modalities", y="AUPRC", color="cornflowerblue")  # all combinations
plt.ylim(0.501)
sns.despine()
plt.savefig('./fig2_model_perf_str_full_with_diff_avail_mods_with_cv_bottleneck.svg', dpi=300, format="svg")
plt.show()

# %% [markdown]
# ### For drugs without certain modalities

# %%
condition_cv_train = between_train_drugs_modality_availability["view_cv"].astype(bool)
condition_kg_train = between_train_drugs_modality_availability["view_kg"].astype(bool)

between_train_set_all_modality_but_kg = set(between_train_drugs_modality_availability[condition_tx_train & condition_cv_train].index.tolist())
between_train_set_all_modality_but_cv = set(between_train_drugs_modality_availability[condition_tx_train & condition_kg_train].index.tolist())
between_train_set_all_modality_but_tx = set(between_train_drugs_modality_availability[condition_kg_train & condition_cv_train].index.tolist())

keep_ddi_train_all_but_kg = []
keep_ddi_train_all_but_cv = []
keep_ddi_train_all_but_tx = []
for i, drug_t in tqdm(enumerate(batch["edge_indices"]["tail"])):
    if batch["tail"]["drugs"][drug_t].item() in between_train_set_all_modality_but_kg:
        keep_ddi_train_all_but_kg.append(i)
    if batch["tail"]["drugs"][drug_t].item() in between_train_set_all_modality_but_cv:
        keep_ddi_train_all_but_cv.append(i)
    if batch["tail"]["drugs"][drug_t].item() in between_train_set_all_modality_but_tx:
        keep_ddi_train_all_but_tx.append(i)
# Out:
# 1165476it [00:05, 232796.73it/s]

# %% [markdown]
# #### No KG

# %%
# Mask train drugs, str-full, no kg
mask_train_str_full_all_but_kg_auprc, avail_mods_all_but_kg_combs = get_label_metrics_all_mod_train(
    model_type="pretrain", 
    checkpoint="madrigal_seed42/", 
    eval_type="str_full", 
    full_mod_drug_set=between_train_set_all_modality_but_kg, 
    keep_ddi=keep_ddi_train_all_but_kg, 
    head_or_tails=["tail"],
)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}

# %%
labels = ['Struc.', 'Struc.\nPKG', 'Struc.\nCV', 'Struc.\nTrans.', 'Struc.\nPKG\nCV', 'Struc.\nPKG\nTrans.', 'Struc.\nCV\nTrans.', 'Struc.\nPKG\nCV\nTrans.']

plt.figure(figsize=(4, 3), dpi=300)
sns.set(style="ticks", context="paper", font_scale=2)
sns.barplot(pd.DataFrame.from_dict({
    "AUPRC": mask_train_str_full_all_but_kg_auprc, 
    "Available modalities": labels
}).iloc[[0, 2, 3, 6], :], x="Available modalities", y="AUPRC", color="cornflowerblue")  # all combinations
plt.ylim(0.501)
sns.despine()
plt.savefig('./fig2_model_perf_str_full_with_diff_avail_mods_all_but_kg_bottleneck.svg', dpi=300, format="svg")
plt.show()

# %% [markdown]
# #### No CV

# %%
# Mask train drugs, str-full, no cv
mask_train_str_full_all_but_cv_auprc, avail_mods_all_but_cv_combs = get_label_metrics_all_mod_train(
    model_type="pretrain", 
    checkpoint="madrigal_seed42/", 
    eval_type="str_full", 
    full_mod_drug_set=between_train_set_all_modality_but_cv, 
    keep_ddi=keep_ddi_train_all_but_cv, 
    head_or_tails=["tail"],
)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}

# %%
labels = ['Struc.', 'Struc.\nPKG', 'Struc.\nCV', 'Struc.\nTrans.', 'Struc.\nPKG\nCV', 'Struc.\nPKG\nTrans.', 'Struc.\nCV\nTrans.', 'Struc.\nPKG\nCV\nTrans.']

plt.figure(figsize=(8, 3), dpi=300)
sns.set(style="ticks", context="paper", font_scale=2)
sns.barplot(pd.DataFrame.from_dict({
    "AUPRC": mask_train_str_full_all_but_cv_auprc, 
    "Available modalities": labels
}).iloc[[0, 1, 3, 5], :], x="Available modalities", y="AUPRC", color="cornflowerblue")  # all combinations
plt.ylim(0.501)
sns.despine()
plt.savefig('./fig2_model_perf_str_full_with_diff_avail_mods_all_but_cv_bottleneck.svg', dpi=300, format="svg")
plt.show()

# %% [markdown]
# #### No Tx

# %%
# Mask train drugs, str-full, no tx
mask_train_str_full_all_but_tx_auprc, avail_mods_all_but_tx_combs = get_label_metrics_all_mod_train(
    model_type="pretrain", 
    checkpoint="madrigal_seed42/", 
    eval_type="str_full", 
    full_mod_drug_set=between_train_set_all_modality_but_tx, 
    keep_ddi=keep_ddi_train_all_but_tx, 
    head_or_tails=["tail"],
)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}
# Using pretrained structure encoder
# Using pretrained KG encoder
# Using pretrained cv encoder
# Using pretrained TX encoder
# INCOMP_KEYS (make sure these contain what you expected):
# %s {   'Missing keys': [   'covariates_embeddings.0.weight'],
#     'Unexpected_keys': [   ]}
# {'Missing keys': [], 'Unexpected_keys': []}

# %%
labels = ['Struc.', 'Struc.\nPKG', 'Struc.\nCV', 'Struc.\nTrans.', 'Struc.\nPKG\nCV', 'Struc.\nPKG\nTrans.', 'Struc.\nCV\nTrans.', 'Struc.\nPKG\nCV\nTrans.']

plt.figure(figsize=(4, 3), dpi=300)
sns.set(style="ticks", context="paper", font_scale=2)
sns.barplot(pd.DataFrame.from_dict({
    "AUPRC": mask_train_str_full_all_but_tx_auprc, 
    "Available modalities": labels
}).iloc[[0, 1, 2, 4], :], x="Available modalities", y="AUPRC", color="cornflowerblue")  # all combinations
plt.ylim(0.501)
sns.despine()
plt.savefig('./fig2_model_perf_str_full_with_diff_avail_mods_all_but_tx_bottleneck.svg', dpi=300, format="svg")
plt.show()
